# %%
#array 사용안하고 전과 같은 방법으로 했을때의 코드
import tensorflow as tf 

x1_data = [73., 93., 89.,96., 73.]
x2_data = [80., 88., 91., 98., 66.]
x3_data = [75., 93., 90., 100., 70.]
y_data = [152., 185., 180., 196., 142.]

x1 = tf.placeholder(tf.float32)
x2 = tf.placeholder(tf.float32)
x3 = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

w1 = tf.Variable(tf.random_normal([1]), name = 'weight1')
w2 = tf.Variable(tf.random_normal([1]), name = 'weight2')
w3 = tf.Variable(tf.random_normal([1]), name = 'weight3')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = x1*w1 + x2*w2 + x3*w3 + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate = 1e-5)
train = optimizer.minimize(cost)
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001): ##train이 return 하는 값은 빈칸으로 (아마 None)
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],\
                                   feed_dict = {x1:x1_data,x2:x2_data,x3:x3_data,Y:y_data})
    if step % 20 == 0:
        print(step, "cost: {} \n hypothesis: {} ".format(cost_val, hy_val))
# Out:
# 0 cost: 52523.21875
#  hypothesis: [-55.190536 -57.463108 -61.341843 -66.764465 -41.32699 ]
# 20 cost: 5.674354076385498
#  hypothesis: [148.16609 186.92166 179.47272 195.47443 145.07016]
# 40 cost: 5.614609718322754
#  hypothesis: [148.18626 186.91135 179.48056 195.48083 145.05547]
# 60 cost: 5.555534362792969
#  hypothesis: [148.20445 186.89888 179.48613 195.48482 145.03912]
# 80 cost: 5.497076511383057
#  hypothesis: [148.22256 186.88647 179.49167 195.4888  145.02289]
# 100 cost: 5.43923807144165
#  hypothesis: [148.24059 186.87413 179.49721 195.49274 145.00674]
# 120 cost: 5.382051944732666
#  hypothesis: [148.2585  186.86186 179.5027  195.49666 144.99069]
# 140 cost: 5.325476169586182
#  hypothesis: [148.2763  186.84966 179.50818 195.50056 144.97472]
# 160 cost: 5.269510746002197
#  hypothesis: [148.29402 186.83751 179.5136  195.50446 144.95883]
# 180 cost: 5.21414041519165
#  hypothesis: [148.31163 186.82544 179.51901 195.50832 144.94301]
# 200 cost: 5.159381866455078
# ...

# %%
import tensorflow as tf 

x_data = [[73,80,75], [93,88,93], [89,91,90], [96,98,100], [73,66,70]]
y_data = [[152], [185], [180], [196], [142]]

X = tf.placeholder(tf.float32, shape = [None, 3])
Y = tf.placeholder(tf.float32, shape = [None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = tf.matmul(X, W) + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate = 1e-5)
train = optimizer.minimize(cost)
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001): ##train이 return 하는 값은 빈칸으로 (아마 None)
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],\
                                   feed_dict = {X : x_data, Y: y_data})
    if step % 20 == 0:
        print(step, "cost: {} \n hypothesis: {} ".format(cost_val, hy_val))
# Out:
# 0 cost: 62092.3671875
#  hypothesis: [[-73.03164 ]
#  [-78.731026]
#  [-82.12314 ]
#  [-89.8281  ]
#  [-57.655506]]
# 20 cost: 5.802217483520508
#  hypothesis: [[148.07513]
#  [186.98788]
#  [179.71242]
#  [195.30217]
#  [145.01416]]
# 40 cost: 5.741752624511719
#  hypothesis: [[148.09555]
#  [186.97772]
#  [179.72044]
#  [195.30884]
#  [144.99947]]
# 60 cost: 5.6819376945495605
#  hypothesis: [[148.11385]
#  [186.96518]
#  [179.72606]
#  [195.31288]
#  [144.98302]]
# 80 cost: 5.622788429260254
#  hypothesis: [[148.13203]
#  [186.95271]
#  [179.73164]
#  [195.31691]
#  [144.96666]]
# 100 cost: 5.564215660095215
#  hypothesis: [[148.15015]
#  [186.94029]
#  [179.73718]
#  [195.3209 ]
#  [144.95038]]
# 120 cost: 5.506337642669678
#  hypothesis: [[148.16814]
#  [186.92795]
#  [179.7427 ]
#  [195.32489]
#  [144.9342 ]]
# 140 cost: 5.449057102203369
#  hypothesis: [[148.18604]
#  [186.91566]
#  [179.74818]
#  [195.32886]
#  [144.9181 ]]
# 160 cost: 5.392383575439453
# ...

# %%
import tensorflow as tf
sess = tf.Session()
sess.run(tf.random_normal([1]))
##tf.random_normal()은 -1~1사이의 값으로 추정됨
# Out:
# array([-0.6642568], dtype=float32)
